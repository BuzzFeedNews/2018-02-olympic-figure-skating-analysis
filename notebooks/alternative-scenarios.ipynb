# %% [markdown]
# # Calculating Alternative Scoring Scenarios
#
# The analysis below calculates the total points and final standings of the ice dance and men's competitions under two alternative scenarios:
#
# 1. The scores of two countries' judges were replaced with the "average" of the rest of the judging panel.
# 2. The scores of two countries' judges were removed from the judging panel entirely.
#
# For ice dance, those countries are Canada and France.
#
# For men's figure skating, those countries are the United States and China.

# %% [markdown]
# ## Load scoring data

# %%
import pandas as pd

# %%
performances = pd.read_csv("../data/performances.csv")
aspects = pd.read_csv("../data/judged-aspects.csv")
scores = pd.read_csv("../data/judge-scores.csv")
judge_goe = pd.read_csv("../data/judge-goe.csv")

# %%
performances.groupby(["program", "competition"])\
    .size().to_frame("performances")
# Out:
#                                                                             performances
# program                                          competition
# Ice Dance - Free Dance                           Olympic Winter Games 2018            20
# Ice Dance - Short Dance                          Olympic Winter Games 2018            24
# Ladies Single Skating - Short Program            Olympic Winter Games 2018            30
# Men Single Skating - Free Skating                Olympic Winter Games 2018            24
# Men Single Skating - Short Program               Olympic Winter Games 2018            30
# Pair Skating - Free Skating                      Olympic Winter Games 2018            16
# Pair Skating - Short Program                     Olympic Winter Games 2018            22
# Team Event - Ice Dance Free Dance                Olympic Winter Games 2018             5
# Team Event - Ice Dance Short Dance               Olympic Winter Games 2018            10
# Team Event - Ladies Single Skating Free Skating  Olympic Winter Games 2018             5
# Team Event - Ladies Single Skating Short Program Olympic Winter Games 2018            10
# Team Event - Men Single Skating Free Skating     Olympic Winter Games 2018             5
# Team Event - Men Single Skating Short Program    Olympic Winter Games 2018            10
# Team Event - Pair Skating Free Skating           Olympic Winter Games 2018             5
# Team Event - Pair Skating Short Program          Olympic Winter Games 2018            10

# %%
scores_with_context = scores.pipe(
    pd.merge,
    aspects,
    on = "aspect_id",
    how = "left"
).pipe(
    pd.merge,
    performances,
    on = "performance_id",
    how = "left"
).pipe(
    pd.merge,
    judge_goe,
    on = [ "aspect_id", "judge" ],
    how = "left"
)

# %%
assert len(scores) == len(scores_with_context)

# %% [markdown]
# ## Set up score-totaling calculations

# %%
# The ISU's scoring system uses a trimmed mean, which removes the highest and 
# lowest score for each element and component.
# To calculate the proper score for a competition, we do the same here.
def calc_trimmed_mean(score_list):
    trimmed = sorted(score_list)[1:-1]
    return round(sum(trimmed) / len(trimmed), 2)

# %%
def calculate_aspect_scores(aspect_judgments):

    aspects_grp = aspect_judgments.groupby("aspect_id")
    
    scores = pd.DataFrame({
        "name": aspects_grp["name"].first(),
        "program": aspects_grp["program"].first(),
        "section": aspects_grp["section"].first(),
        "performance_id": aspects_grp["performance_id"].first(),
        "factor": aspects_grp["factor"].first(),
        "base_value": aspects_grp["base_value"].first(),
        "score": aspects_grp["score"].apply(lambda x: calc_trimmed_mean(x)),
        "judge_goe": aspects_grp["judge_goe"].apply(lambda x: calc_trimmed_mean(x)),
        "total_deductions": aspects_grp["total_deductions"].first()
    })
    
    return scores

# %%
def total_points(row):
    if row["section"] == "elements":
        return round(row["base_value"] + row["judge_goe"], 2)
    
    elif row["section"] == "components":
        return round(row["factor"] * row["score"], 2)
    
    else:
        print("Unknown section: {}".format(row["section"]))
        return None

# %%
def calculate_results(scores):
    
    scores["total_points"] = scores.apply(total_points, axis=1)
    
    perfs_grp = scores.groupby("performance_id")
    
    perfs = pd.DataFrame({
        "score": perfs_grp["total_points"].sum(),
        "deductions": perfs_grp["total_deductions"].first(),
        "program": perfs_grp["program"].first(),
        "name": perfs_grp["name"].first()
    })
    
    perfs["total_score"] = perfs["score"] - perfs["deductions"]
    
    comp_grp = perfs.groupby("name")
    
    results = pd.DataFrame({
        "final_score": comp_grp["total_score"].sum()
     })
    
    return results

# %%
def calc_trimmed_mean_with_average_judge(score_list):
    average = sum(score_list) / len(score_list)
    score_list = score_list.tolist() + [average] * (9-len(score_list))
    trimmed = sorted(score_list)[1:-1]
    return round(sum(trimmed) / len(trimmed), 2)

# %%
def calculate_score_with_average_judge(dataframe):

    aspects = dataframe.groupby("aspect_id")
    
    scores = pd.DataFrame({
        "name": aspects["name"].first(),
        "program": aspects["program"].first(),
        "section": aspects["section"].first(),
        "performance_id": aspects["performance_id"].first(),
        "factor": aspects["factor"].first(),
        "base_value": aspects["base_value"].first(),
        "scores_of_panel": aspects["scores_of_panel"].first(),
        "score": aspects["score"].apply(lambda x: calc_trimmed_mean_with_average_judge(x)),
        "judge_goe": aspects["judge_goe"].apply(lambda x: calc_trimmed_mean_with_average_judge(x)),
        "total_deductions": aspects["total_deductions"].first()
    })
    
    return scores

# %% [markdown]
# ---
#
# ## Ice Dance Calculations

# %% [markdown]
# ### Create subsets of scores with/without Canadian and French judges

# %%
id_olympics = scores_with_context[
    scores_with_context["program"].str.contains("Ice Dance") &
    ~scores_with_context["program"].str.contains("Team")
].copy()

# %%
id_olympics\
    .groupby([ "program", "judge"])\
    .size().unstack()\
    .fillna(0).astype(int)
# Out:
# judge                     J1   J2   J3   J4   J5   J6   J7   J8   J9
# program
# Ice Dance - Free Dance   277  277  277  277  277  277  277  277  277
# Ice Dance - Short Dance  240  240  240  240  240  240  240  240  240

# %%
id_olympics_without_canada_france = id_olympics[
    ~(
        # Canada
        (
            (id_olympics["judge"] == "J1") &
            (id_olympics["program"] == "Ice Dance - Short Dance")
        ) |
        (
            (id_olympics["judge"] == "J2") &
            (id_olympics["program"] == "Ice Dance - Free Dance")
        ) |
      
        # France
        (

            (id_olympics["judge"] == "J4") &
            (id_olympics["program"] == "Ice Dance - Short Dance")
        )
    )
].copy()

# %%
id_olympics_without_canada_france\
    .groupby([ "program", "judge"])\
    .size().unstack()\
    .fillna(0).astype(int)
# Out:
# judge                     J1   J2   J3   J4   J5   J6   J7   J8   J9
# program
# Ice Dance - Free Dance   277    0  277  277  277  277  277  277  277
# Ice Dance - Short Dance    0  240  240    0  240  240  240  240  240

# %% [markdown]
# ### Calculate actual and alternate scoring scenarios for Ice Dance

# %%
aspect_scores = calculate_aspect_scores(id_olympics)
final_actual = calculate_results(aspect_scores)\
    .sort_values("final_score", ascending=False)

# %%
scores_with_replacement = calculate_score_with_average_judge(id_olympics_without_canada_france)
final_with_replacement = calculate_results(scores_with_replacement)\
    .sort_values("final_score", ascending=False)

# %%
scores_no_replacement = calculate_aspect_scores(id_olympics_without_canada_france)
final_with_removal = calculate_results(scores_no_replacement)\
    .sort_values("final_score", ascending=False)

# %% [markdown]
# ### Actual scores vs. scores with CAN/FRA replaced by "average" judgments

# %%
pd.merge(
    final_actual.reset_index(),
    final_with_replacement.reset_index(),
    on="name",
    suffixes=["_actual", "_with_replacement"]
).set_index("name")\
    .assign(
        rank_actual = lambda x: x["final_score_actual"]\
            .rank(ascending = False)\
            .astype(int),
        rank_with_replacement = lambda x: x["final_score_with_replacement"]\
            .rank(ascending = False)\
            .astype(int),
    )
# Out:
#                                          final_score_actual  \
# name
# VIRTUE Tessa / MOIR Scott                            206.07
# PAPADAKIS Gabriella / CIZERON Guillaume              205.28
# SHIBUTANI Maia / SHIBUTANI Alex                      192.59
# HUBBELL Madison / DONOHUE Zachary                    189.69
# BOBROVA Ekaterina / SOLOVIEV Dmitri                  186.92
# CAPPELLINI Anna / LANOTTE Luca                       186.91
# WEAVER Kaitlyn / POJE Andrew                         181.98
# CHOCK Madison / BATES Evan                           179.58
# GILLES Piper / POIRIER Paul                          176.91
# GUIGNARD Charlene / FABBRI Marco                     173.47
# COOMES Penny / BUCKLAND Nicholas                     170.32
# HURTADO Sara / KHALIAVIN Kirill                      168.33
# ZAGORSKI Tiffani / GUERREIRO Jonathan                162.24
# KALISZEK Natalia / SPODYRIEV Maksym                  161.35
# MURAMOTO Kana / REED Chris                           160.63
# LORENZ Kavita / POLIZOAKIS Joti                      150.49
# LAURIAULT Marie-Jade / le GAC Romain                 149.59
# MIN Yura / GAMELIN Alexander                         147.74
# AGAFONOVA Alisa / UCAR Alper                         147.18
# MYSLIVECKOVA Lucie / CSOLLEY Lukas                   142.57
# WANG Shiyue / LIU Xinyu                               59.81
# NAZAROVA Alexandra / NIKITIN Maxim                    57.97
# MANSOUROVA Cortney / CESKA Michal                     53.53
# TANKOVA Adel / ZILBERBERG Ronald                      46.66
#
#                                          final_score_with_replacement  \
# name
# VIRTUE Tessa / MOIR Scott                                      205.74
# PAPADAKIS Gabriella / CIZERON Guillaume                        206.13
# SHIBUTANI Maia / SHIBUTANI Alex                                192.27
# HUBBELL Madison / DONOHUE Zachary                              189.48
# BOBROVA Ekaterina / SOLOVIEV Dmitri                            187.76
# CAPPELLINI Anna / LANOTTE Luca                                 186.99
# WEAVER Kaitlyn / POJE Andrew                                   180.31
# CHOCK Madison / BATES Evan                                     178.95
# GILLES Piper / POIRIER Paul                                    176.18
# GUIGNARD Charlene / FABBRI Marco                               173.09
# COOMES Penny / BUCKLAND Nicholas                               169.77
# HURTADO Sara / KHALIAVIN Kirill                                169.07
# ZAGORSKI Tiffani / GUERREIRO Jonathan                          162.64
# KALISZEK Natalia / SPODYRIEV Maksym                            162.16
# MURAMOTO Kana / REED Chris                                     159.89
# LORENZ Kavita / POLIZOAKIS Joti                                149.67
# LAURIAULT Marie-Jade / le GAC Romain                           149.63
# MIN Yura / GAMELIN Alexander                                   147.24
# AGAFONOVA Alisa / UCAR Alper                                   148.78
# MYSLIVECKOVA Lucie / CSOLLEY Lukas                             143.39
# WANG Shiyue / LIU Xinyu                                         60.48
# NAZAROVA Alexandra / NIKITIN Maxim                              58.34
# MANSOUROVA Cortney / CESKA Michal                               53.94
# TANKOVA Adel / ZILBERBERG Ronald                                46.96
#
#                                          rank_actual  rank_with_replacement
# name
# VIRTUE Tessa / MOIR Scott                          1                      2
# PAPADAKIS Gabriella / CIZERON Guillaume            2                      1
# SHIBUTANI Maia / SHIBUTANI Alex                    3                      3
# HUBBELL Madison / DONOHUE Zachary                  4                      4
# BOBROVA Ekaterina / SOLOVIEV Dmitri                5                      5
# CAPPELLINI Anna / LANOTTE Luca                     6                      6
# WEAVER Kaitlyn / POJE Andrew                       7                      7
# CHOCK Madison / BATES Evan                         8                      8
# GILLES Piper / POIRIER Paul                        9                      9
# GUIGNARD Charlene / FABBRI Marco                  10                     10
# COOMES Penny / BUCKLAND Nicholas                  11                     11
# HURTADO Sara / KHALIAVIN Kirill                   12                     12
# ZAGORSKI Tiffani / GUERREIRO Jonathan             13                     13
# KALISZEK Natalia / SPODYRIEV Maksym               14                     14
# MURAMOTO Kana / REED Chris                        15                     15
# LORENZ Kavita / POLIZOAKIS Joti                   16                     16
# LAURIAULT Marie-Jade / le GAC Romain              17                     17
# MIN Yura / GAMELIN Alexander                      18                     19
# AGAFONOVA Alisa / UCAR Alper                      19                     18
# MYSLIVECKOVA Lucie / CSOLLEY Lukas                20                     20
# WANG Shiyue / LIU Xinyu                           21                     21
# NAZAROVA Alexandra / NIKITIN Maxim                22                     22
# MANSOUROVA Cortney / CESKA Michal                 23                     23
# TANKOVA Adel / ZILBERBERG Ronald                  24                     24

# %% [markdown]
# ### Actual scores vs. scores with CAN/FRA removed (and not replaced)

# %%
pd.merge(
    final_actual.reset_index(),
    final_with_removal.reset_index(),
    on="name",
    suffixes=["_actual", "_with_removal"]
).set_index("name")\
    .assign(
        rank_actual = lambda x: x["final_score_actual"]\
            .rank(ascending = False)\
            .astype(int),
        rank_with_removal = lambda x: x["final_score_with_removal"]\
            .rank(ascending = False)\
            .astype(int),
    )
# Out:
#                                          final_score_actual  \
# name
# VIRTUE Tessa / MOIR Scott                            206.07
# PAPADAKIS Gabriella / CIZERON Guillaume              205.28
# SHIBUTANI Maia / SHIBUTANI Alex                      192.59
# HUBBELL Madison / DONOHUE Zachary                    189.69
# BOBROVA Ekaterina / SOLOVIEV Dmitri                  186.92
# CAPPELLINI Anna / LANOTTE Luca                       186.91
# WEAVER Kaitlyn / POJE Andrew                         181.98
# CHOCK Madison / BATES Evan                           179.58
# GILLES Piper / POIRIER Paul                          176.91
# GUIGNARD Charlene / FABBRI Marco                     173.47
# COOMES Penny / BUCKLAND Nicholas                     170.32
# HURTADO Sara / KHALIAVIN Kirill                      168.33
# ZAGORSKI Tiffani / GUERREIRO Jonathan                162.24
# KALISZEK Natalia / SPODYRIEV Maksym                  161.35
# MURAMOTO Kana / REED Chris                           160.63
# LORENZ Kavita / POLIZOAKIS Joti                      150.49
# LAURIAULT Marie-Jade / le GAC Romain                 149.59
# MIN Yura / GAMELIN Alexander                         147.74
# AGAFONOVA Alisa / UCAR Alper                         147.18
# MYSLIVECKOVA Lucie / CSOLLEY Lukas                   142.57
# WANG Shiyue / LIU Xinyu                               59.81
# NAZAROVA Alexandra / NIKITIN Maxim                    57.97
# MANSOUROVA Cortney / CESKA Michal                     53.53
# TANKOVA Adel / ZILBERBERG Ronald                      46.66
#
#                                          final_score_with_removal  \
# name
# VIRTUE Tessa / MOIR Scott                                  205.86
# PAPADAKIS Gabriella / CIZERON Guillaume                    206.32
# SHIBUTANI Maia / SHIBUTANI Alex                            192.27
# HUBBELL Madison / DONOHUE Zachary                          189.42
# BOBROVA Ekaterina / SOLOVIEV Dmitri                        187.97
# CAPPELLINI Anna / LANOTTE Luca                             187.00
# WEAVER Kaitlyn / POJE Andrew                               180.34
# CHOCK Madison / BATES Evan                                 178.83
# GILLES Piper / POIRIER Paul                                176.22
# GUIGNARD Charlene / FABBRI Marco                           173.19
# COOMES Penny / BUCKLAND Nicholas                           169.86
# HURTADO Sara / KHALIAVIN Kirill                            169.08
# ZAGORSKI Tiffani / GUERREIRO Jonathan                      162.68
# KALISZEK Natalia / SPODYRIEV Maksym                        162.31
# MURAMOTO Kana / REED Chris                                 159.90
# LORENZ Kavita / POLIZOAKIS Joti                            149.80
# LAURIAULT Marie-Jade / le GAC Romain                       149.57
# MIN Yura / GAMELIN Alexander                               147.25
# AGAFONOVA Alisa / UCAR Alper                               148.93
# MYSLIVECKOVA Lucie / CSOLLEY Lukas                         143.37
# WANG Shiyue / LIU Xinyu                                     60.62
# NAZAROVA Alexandra / NIKITIN Maxim                          58.34
# MANSOUROVA Cortney / CESKA Michal                           54.02
# TANKOVA Adel / ZILBERBERG Ronald                            46.98
#
#                                          rank_actual  rank_with_removal
# name
# VIRTUE Tessa / MOIR Scott                          1                  2
# PAPADAKIS Gabriella / CIZERON Guillaume            2                  1
# SHIBUTANI Maia / SHIBUTANI Alex                    3                  3
# HUBBELL Madison / DONOHUE Zachary                  4                  4
# BOBROVA Ekaterina / SOLOVIEV Dmitri                5                  5
# CAPPELLINI Anna / LANOTTE Luca                     6                  6
# WEAVER Kaitlyn / POJE Andrew                       7                  7
# CHOCK Madison / BATES Evan                         8                  8
# GILLES Piper / POIRIER Paul                        9                  9
# GUIGNARD Charlene / FABBRI Marco                  10                 10
# COOMES Penny / BUCKLAND Nicholas                  11                 11
# HURTADO Sara / KHALIAVIN Kirill                   12                 12
# ZAGORSKI Tiffani / GUERREIRO Jonathan             13                 13
# KALISZEK Natalia / SPODYRIEV Maksym               14                 14
# MURAMOTO Kana / REED Chris                        15                 15
# LORENZ Kavita / POLIZOAKIS Joti                   16                 16
# LAURIAULT Marie-Jade / le GAC Romain              17                 17
# MIN Yura / GAMELIN Alexander                      18                 19
# AGAFONOVA Alisa / UCAR Alper                      19                 18
# MYSLIVECKOVA Lucie / CSOLLEY Lukas                20                 20
# WANG Shiyue / LIU Xinyu                           21                 21
# NAZAROVA Alexandra / NIKITIN Maxim                22                 22
# MANSOUROVA Cortney / CESKA Michal                 23                 23
# TANKOVA Adel / ZILBERBERG Ronald                  24                 24

# %% [markdown]
# ---
#
# ## Men's Figure Skating Calculations

# %% [markdown]
# ### Create subsets of scores with/without American and Chinese judges

# %%
men_olympics = scores_with_context[
    scores_with_context["program"].str.contains("Men") &
    ~scores_with_context["program"].str.contains("Team")
].copy()

# %%
men_olympics\
    .groupby([ "program", "judge"])\
    .size().unstack()\
    .fillna(0).astype(int)
# Out:
# judge                                J1   J2   J3   J4   J5   J6   J7   J8  \
# program
# Men Single Skating - Free Skating   432  432  432  432  432  432  432  432
# Men Single Skating - Short Program  358  358  358  358  358  358  358  358
#
# judge                                J9
# program
# Men Single Skating - Free Skating   432
# Men Single Skating - Short Program  358

# %%
men_olympics_without_usa_china = men_olympics[
    ~(
        # China
        (
            (men_olympics["judge"] == "J9") &
            (men_olympics["program"] == "Men Single Skating - Short Program")
        ) |
        (
            (men_olympics["judge"] == "J7") &
            (men_olympics["program"] == "Men Single Skating - Free Skating")
        ) |
      
        # United States
        (

            (men_olympics["judge"] == "J2") &
            (men_olympics["program"] == "Men Single Skating - Free Skating")
        )
    )
].copy()

# %%
men_olympics_without_usa_china\
    .groupby([ "program", "judge"])\
    .size().unstack()\
    .fillna(0).astype(int)
# Out:
# judge                                J1   J2   J3   J4   J5   J6   J7   J8  \
# program
# Men Single Skating - Free Skating   432    0  432  432  432  432    0  432
# Men Single Skating - Short Program  358  358  358  358  358  358  358  358
#
# judge                                J9
# program
# Men Single Skating - Free Skating   432
# Men Single Skating - Short Program    0

# %% [markdown]
# ### Calculate actual and alternate scoring scenarios for Men

# %%
men_aspect_scores = calculate_aspect_scores(men_olympics)
men_final_actual = calculate_results(men_aspect_scores)\
    .sort_values("final_score", ascending=False)

# %%
men_scores_with_replacement = calculate_score_with_average_judge(men_olympics_without_usa_china)
men_final_with_replacement = calculate_results(men_scores_with_replacement)\
    .sort_values("final_score", ascending=False)

# %%
men_scores_no_replacement = calculate_aspect_scores(men_olympics_without_usa_china)
men_final_with_removal = calculate_results(men_scores_no_replacement)\
    .sort_values("final_score", ascending=False)

# %% [markdown]
# ### Actual scores vs. scores with CHN/USA replaced by "average" judgments

# %%
pd.merge(
    men_final_actual.reset_index(),
    men_final_with_replacement.reset_index(),
    on="name",
    suffixes=["_actual", "_with_replacement"]
).set_index("name")\
    .assign(
        rank_actual = lambda x: x["final_score_actual"]\
            .rank(ascending = False)\
            .astype(int),
        rank_with_replacement = lambda x: x["final_score_with_replacement"]\
            .rank(ascending = False)\
            .astype(int),
    )
# Out:
#                             final_score_actual  final_score_with_replacement  \
# name
# HANYU Yuzuru                            317.85                        318.68
# UNO Shoma                               308.90                        310.34
# FERNANDEZ Javier                        305.24                        307.01
# JIN Boyang                              299.77                        298.09
# CHEN Nathan                             299.35                        298.73
# ZHOU Vincent                            276.69                        275.75
# ALIEV Dmitri                            271.51                        272.60
# KOLYADA Mikhail                         270.25                        271.83
# CHAN Patrick                            265.43                        264.71
# RIPPON Adam                             259.36                        258.19
# MESSING Keegan                          257.43                        257.55
# BYCHENKO Alexei                         257.01                        258.35
# SAMOHIN Daniel                          253.44                        253.42
# TANAKA Keiji                            250.83                        251.18
# CHA Junhwan                             250.59                        249.17
# HENDRICKX Jorik                         248.95                        248.56
# BREZINA Michal                          246.07                        246.73
# GE Misha                                244.94                        244.19
# VASILJEVS Deniss                        240.58                        240.39
# KERRY Brendan                           233.81                        232.81
# RIZZO Matteo                            232.41                        232.66
# KVITELASHVILI Morisi                    218.57                        218.91
# YAN Han                                 217.01                        215.56
# FENTZ Paul                              214.55                        214.42
# YEE Julian Zhi Jie                       73.58                         73.80
# BESSEGHIER Chafik                        72.10                         72.40
# TEN Denis                                70.12                         70.56
# MARTINEZ Michael Christian               55.56                         55.15
# MONTOYA Felipe                           54.41                         54.49
# PANIOT Yaroslav                          50.58                         50.51
#
#                             rank_actual  rank_with_replacement
# name
# HANYU Yuzuru                          1                      1
# UNO Shoma                             2                      2
# FERNANDEZ Javier                      3                      3
# JIN Boyang                            4                      5
# CHEN Nathan                           5                      4
# ZHOU Vincent                          6                      6
# ALIEV Dmitri                          7                      7
# KOLYADA Mikhail                       8                      8
# CHAN Patrick                          9                      9
# RIPPON Adam                          10                     11
# MESSING Keegan                       11                     12
# BYCHENKO Alexei                      12                     10
# SAMOHIN Daniel                       13                     13
# TANAKA Keiji                         14                     14
# CHA Junhwan                          15                     15
# HENDRICKX Jorik                      16                     16
# BREZINA Michal                       17                     17
# GE Misha                             18                     18
# VASILJEVS Deniss                     19                     19
# KERRY Brendan                        20                     20
# RIZZO Matteo                         21                     21
# KVITELASHVILI Morisi                 22                     22
# YAN Han                              23                     23
# FENTZ Paul                           24                     24
# YEE Julian Zhi Jie                   25                     25
# BESSEGHIER Chafik                    26                     26
# TEN Denis                            27                     27
# MARTINEZ Michael Christian           28                     28
# MONTOYA Felipe                       29                     29
# PANIOT Yaroslav                      30                     30

# %% [markdown]
# ### Actual scores vs. scores with CHN/USA removed (and not replaced)

# %%
pd.merge(
    men_final_actual.reset_index(),
    men_final_with_removal.reset_index(),
    on="name",
    suffixes=["_actual", "_with_removal"]
).set_index("name")\
    .assign(
        rank_actual = lambda x: x["final_score_actual"]\
            .rank(ascending = False)\
            .astype(int),
        rank_with_removal = lambda x: x["final_score_with_removal"]\
            .rank(ascending = False)\
            .astype(int),
    )
# Out:
#                             final_score_actual  final_score_with_removal  \
# name
# HANYU Yuzuru                            317.85                    318.80
# UNO Shoma                               308.90                    310.44
# FERNANDEZ Javier                        305.24                    307.14
# JIN Boyang                              299.77                    298.15
# CHEN Nathan                             299.35                    298.82
# ZHOU Vincent                            276.69                    275.80
# ALIEV Dmitri                            271.51                    272.63
# KOLYADA Mikhail                         270.25                    271.92
# CHAN Patrick                            265.43                    264.67
# RIPPON Adam                             259.36                    258.23
# MESSING Keegan                          257.43                    257.46
# BYCHENKO Alexei                         257.01                    258.34
# SAMOHIN Daniel                          253.44                    253.48
# TANAKA Keiji                            250.83                    251.34
# CHA Junhwan                             250.59                    249.18
# HENDRICKX Jorik                         248.95                    248.54
# BREZINA Michal                          246.07                    246.70
# GE Misha                                244.94                    244.16
# VASILJEVS Deniss                        240.58                    240.35
# KERRY Brendan                           233.81                    232.70
# RIZZO Matteo                            232.41                    232.54
# KVITELASHVILI Morisi                    218.57                    218.89
# YAN Han                                 217.01                    215.78
# FENTZ Paul                              214.55                    214.26
# YEE Julian Zhi Jie                       73.58                     73.75
# BESSEGHIER Chafik                        72.10                     72.41
# TEN Denis                                70.12                     70.56
# MARTINEZ Michael Christian               55.56                     55.15
# MONTOYA Felipe                           54.41                     54.47
# PANIOT Yaroslav                          50.58                     50.51
#
#                             rank_actual  rank_with_removal
# name
# HANYU Yuzuru                          1                  1
# UNO Shoma                             2                  2
# FERNANDEZ Javier                      3                  3
# JIN Boyang                            4                  5
# CHEN Nathan                           5                  4
# ZHOU Vincent                          6                  6
# ALIEV Dmitri                          7                  7
# KOLYADA Mikhail                       8                  8
# CHAN Patrick                          9                  9
# RIPPON Adam                          10                 11
# MESSING Keegan                       11                 12
# BYCHENKO Alexei                      12                 10
# SAMOHIN Daniel                       13                 13
# TANAKA Keiji                         14                 14
# CHA Junhwan                          15                 15
# HENDRICKX Jorik                      16                 16
# BREZINA Michal                       17                 17
# GE Misha                             18                 18
# VASILJEVS Deniss                     19                 19
# KERRY Brendan                        20                 20
# RIZZO Matteo                         21                 21
# KVITELASHVILI Morisi                 22                 22
# YAN Han                              23                 23
# FENTZ Paul                           24                 24
# YEE Julian Zhi Jie                   25                 25
# BESSEGHIER Chafik                    26                 26
# TEN Denis                            27                 27
# MARTINEZ Michael Christian           28                 28
# MONTOYA Felipe                       29                 29
# PANIOT Yaroslav                      30                 30

# %% [markdown]
# ---
#
# ---
#
# ---
